# %% [markdown]
# # Initialization

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb
import pandas as pd
import numpy as np

# %% [markdown]
# Preparing the **dataset** for training and evaluating

# %%
data = pd.read_csv('./cleaned_train.csv', index_col = 0)
data.describe()
# Out:
#        OverallQual    YearBuilt  YearRemodAdd    ExterQual    ExterCond  \
# count  1457.000000  1457.000000   1457.000000  1457.000000  1457.000000
# mean      6.094715  1971.194235   1984.818806     3.785175     4.611531
# std       1.376542    30.190353     20.640669     1.597508     1.054206
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     2.000000     5.000000
# 50%       6.000000  1972.000000   1994.000000     5.000000     5.000000
# 75%       7.000000  2000.000000   2004.000000     5.000000     5.000000
# max      10.000000  2010.000000   2010.000000     5.000000     5.000000
#
#          BsmtFinSF1     BsmtUnfSF   TotalBsmtSF    HeatingQC      2ndFlrSF  \
# count  1.457000e+03  1.457000e+03  1.457000e+03  1457.000000  1.457000e+03
# mean   4.267158e-18 -5.132781e-16 -4.740355e-16     1.834592 -1.680955e-16
# std    8.250042e-01  9.589801e-01  9.875600e-01     2.164451  6.567486e-01
# min   -2.508631e+00 -2.726576e+00 -4.987976e+00     0.000000 -3.524366e+00
# 25%   -2.889312e-01 -6.385582e-01 -6.470418e-01     0.000000  0.000000e+00
# 50%    0.000000e+00  0.000000e+00 -4.024282e-02     0.000000  0.000000e+00
# 75%    2.932680e-01  6.285000e-01  6.684488e-01     5.000000  0.000000e+00
# max    3.086749e+00  2.585456e+00  3.702579e+00     5.000000  3.695110e+00
#
#        ...  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# count  ...     1457.000000     1457.000000   1457.000000   1457.000000
# mean   ...        0.003432        0.003432      0.082361      0.002059
# std    ...        0.058500        0.058500      0.275008      0.045345
# min    ...        0.000000        0.000000      0.000000      0.000000
# 25%    ...        0.000000        0.000000      0.000000      0.000000
# 50%    ...        0.000000        0.000000      0.000000      0.000000
# 75%    ...        0.000000        0.000000      0.000000      0.000000
# max    ...        1.000000        1.000000      1.000000      1.000000
#
#        SaleType_WD  SaleCondition_AdjLand  SaleCondition_Alloca  \
# count  1457.000000            1457.000000           1457.000000
# mean      0.868909               0.002745              0.008236
# std       0.337616               0.052342              0.090410
# min       0.000000               0.000000              0.000000
# 25%       1.000000               0.000000              0.000000
# 50%       1.000000               0.000000              0.000000
# 75%       1.000000               0.000000              0.000000
# max       1.000000               1.000000              1.000000
#
#        SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# count           1457.000000           1457.000000            1457.000000
# mean               0.013727              0.821551               0.084420
# std                0.116395              0.383022               0.278112
# min                0.000000              0.000000               0.000000
# 25%                0.000000              1.000000               0.000000
# 50%                0.000000              1.000000               0.000000
# 75%                0.000000              1.000000               0.000000
# max                1.000000              1.000000               1.000000
#
# [8 rows x 77 columns]

# %%
test = pd.read_csv('./cleaned_test.csv', index_col = 0)
test.describe()
# Out:
#                 Id  OverallQual    YearBuilt  YearRemodAdd    ExterQual  \
# count  1459.000000  1459.000000  1459.000000   1459.000000  1459.000000
# mean   2190.000000     6.078821  1971.357779   1983.662783     3.744345
# std     421.321334     1.436812    30.390071     21.130467     1.620691
# min    1461.000000     1.000000  1879.000000   1950.000000     0.000000
# 25%    1825.500000     5.000000  1953.000000   1963.000000     2.000000
# 50%    2190.000000     6.000000  1973.000000   1992.000000     5.000000
# 75%    2554.500000     7.000000  2001.000000   2004.000000     5.000000
# max    2919.000000    10.000000  2010.000000   2010.000000     5.000000
#
#          ExterCond    BsmtFinSF1     BsmtUnfSF   TotalBsmtSF    HeatingQC  \
# count  1459.000000  1.459000e+03  1.459000e+03  1.459000e+03  1459.000000
# mean      4.546265 -6.445229e-17  1.801925e-16  3.743388e-16     1.824537
# std       1.149828  8.265153e-01  9.568897e-01  9.858394e-01     2.171502
# min       0.000000 -2.306754e+00 -2.645587e+00 -3.656306e+00     0.000000
# 25%       5.000000 -2.967805e-01 -6.503426e-01 -5.775882e-01     0.000000
# 50%       5.000000  0.000000e+00  0.000000e+00 -1.475348e-02     0.000000
# 75%       5.000000  4.122764e-01  6.387899e-01  6.537297e-01     5.000000
# max       5.000000  4.705638e+00  2.417964e+00  5.504799e+00     5.000000
#
#        ...  SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  \
# count  ...     1459.000000     1459.000000   1459.000000   1459.000000
# mean   ...        0.002742        0.002056      0.080192      0.002742
# std    ...        0.052306        0.045314      0.271683      0.052306
# min    ...        0.000000        0.000000      0.000000      0.000000
# 25%    ...        0.000000        0.000000      0.000000      0.000000
# 50%    ...        0.000000        0.000000      0.000000      0.000000
# 75%    ...        0.000000        0.000000      0.000000      0.000000
# max    ...        1.000000        1.000000      1.000000      1.000000
#
#        SaleType_WD  SaleCondition_AdjLand  SaleCondition_Alloca  \
# count   1459.00000            1459.000000           1459.000000
# mean       0.86292               0.005483              0.008225
# std        0.34405               0.073871              0.090348
# min        0.00000               0.000000              0.000000
# 25%        1.00000               0.000000              0.000000
# 50%        1.00000               0.000000              0.000000
# 75%        1.00000               0.000000              0.000000
# max        1.00000               1.000000              1.000000
#
#        SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# count           1459.000000           1459.000000            1459.000000
# mean               0.017820              0.825223               0.082248
# std                0.132344              0.379907               0.274837
# min                0.000000              0.000000               0.000000
# 25%                0.000000              1.000000               0.000000
# 50%                0.000000              1.000000               0.000000
# 75%                0.000000              1.000000               0.000000
# max                1.000000              1.000000               1.000000
#
# [8 rows x 77 columns]

# %%
x_train = data.drop(labels=['SalePrice'],axis=1,inplace=False)
y_train = data['SalePrice'].values
x_train.reset_index(inplace=True, drop=True)

# %%
test_id = test['Id']
x_test = test.drop(labels=['Id'], axis=1)
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 0 to 1458
# Data columns (total 76 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OverallQual            1459 non-null   int64
#  1   YearBuilt              1459 non-null   int64
#  2   YearRemodAdd           1459 non-null   int64
#  3   ExterQual              1459 non-null   int64
#  4   ExterCond              1459 non-null   int64
#  5   BsmtFinSF1             1459 non-null   float64
#  6   BsmtUnfSF              1459 non-null   float64
#  7   TotalBsmtSF            1459 non-null   float64
#  8   HeatingQC              1459 non-null   int64
#  9   2ndFlrSF               1459 non-null   float64
#  10  GrLivArea              1459 non-null   float64
#  11  FullBath               1459 non-null   int64
#  12  KitchenQual            1459 non-null   int64
#  13  Fireplaces             1459 non-null   int64
#  14  GarageCars             1459 non-null   float64
#  15  MSZoning_FV            1459 non-null   float64
#  16  MSZoning_RH            1459 non-null   float64
#  17  MSZoning_RL            1459 non-null   float64
#  18  MSZoning_RM            1459 non-null   float64
#  19  Street_Pave            1459 non-null   float64
#  20  LotShape_IR2           1459 non-null   float64
#  21  LotShape_IR3           1459 non-null   float64
#  22  LotShape_Reg           1459 non-null   float64
#  23  Condition1_Feedr       1459 non-null   float64
#  24  Condition1_Norm        1459 non-null   float64
#  25  Condition1_PosA        1459 non-null   float64
#  26  Condition1_PosN        1459 non-null   float64
#  27  Condition1_RRAe        1459 non-null   float64
#  28  Condition1_RRAn        1459 non-null   float64
#  29  Condition1_RRNe        1459 non-null   float64
#  30  Condition1_RRNn        1459 non-null   float64
#  31  Condition2_Feedr       1459 non-null   float64
#  32  Condition2_Norm        1459 non-null   float64
#  33  Condition2_PosA        1459 non-null   float64
#  34  Condition2_PosN        1459 non-null   float64
#  35  Condition2_RRAe        1459 non-null   float64
#  36  Condition2_RRAn        1459 non-null   float64
#  37  Condition2_RRNn        1459 non-null   float64
#  38  HouseStyle_1.5Unf      1459 non-null   float64
#  39  HouseStyle_1Story      1459 non-null   float64
#  40  HouseStyle_2.5Fin      1459 non-null   float64
#  41  HouseStyle_2.5Unf      1459 non-null   float64
#  42  HouseStyle_2Story      1459 non-null   float64
#  43  HouseStyle_SFoyer      1459 non-null   float64
#  44  HouseStyle_SLvl        1459 non-null   float64
#  45  RoofMatl_Membran       1459 non-null   float64
#  46  RoofMatl_Metal         1459 non-null   float64
#  47  RoofMatl_Roll          1459 non-null   float64
#  48  RoofMatl_Tar&Grv       1459 non-null   float64
#  49  RoofMatl_WdShake       1459 non-null   float64
#  50  RoofMatl_WdShngl       1459 non-null   float64
#  51  Heating_GasA           1459 non-null   float64
#  52  Heating_GasW           1459 non-null   float64
#  53  Heating_Grav           1459 non-null   float64
#  54  Heating_OthW           1459 non-null   float64
#  55  Heating_Wall           1459 non-null   float64
#  56  CentralAir_Y           1459 non-null   float64
#  57  Electrical_FuseF       1459 non-null   float64
#  58  Electrical_FuseP       1459 non-null   float64
#  59  Electrical_Mix         1459 non-null   float64
#  60  Electrical_SBrkr       1459 non-null   float64
#  61  PavedDrive_P           1459 non-null   float64
#  62  PavedDrive_Y           1459 non-null   float64
#  63  SaleType_CWD           1459 non-null   float64
#  64  SaleType_Con           1459 non-null   float64
#  65  SaleType_ConLD         1459 non-null   float64
#  66  SaleType_ConLI         1459 non-null   float64
#  67  SaleType_ConLw         1459 non-null   float64
#  68  SaleType_New           1459 non-null   float64
#  69  SaleType_Oth           1459 non-null   float64
#  70  SaleType_WD            1459 non-null   float64
#  71  SaleCondition_AdjLand  1459 non-null   float64
#  72  SaleCondition_Alloca   1459 non-null   float64
#  73  SaleCondition_Family   1459 non-null   float64
#  74  SaleCondition_Normal   1459 non-null   float64
#  75  SaleCondition_Partial  1459 non-null   float64
# dtypes: float64(67), int64(9)
# memory usage: 877.7 KB

# %% [markdown]
# Using **Cross validation** strategy to evaluate my models

# %%
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=17).get_n_splits(x_train.values)
    mse= np.sqrt(-cross_val_score(model, x_train.values, y_train, scoring="neg_mean_squared_log_error", cv = kf))
    return(mse)

# %% [markdown]
# # Models

# %% [markdown]
# **LASSO Regression** :
# This model may be very sensitive to outliers. So we need to made it more robust on them. For that we use the sklearn's **Robustscaler()** method on pipeline

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=17))

# %% [markdown]
# **Elastic Net Regression** :
# again made robust to outliers

# %%
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))

# %% [markdown]
# **Kernel Ridge Regression**:

# %%
KRR = KernelRidge(alpha=1, kernel='polynomial', degree=2, coef0=2.5)

# %% [markdown]
# **Gradient Boosting Regression**:
# With huber loss that makes it robust to outliers

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

# %% [markdown]
# **XGBoost**:

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %% [markdown]
# **LightGBM**:

# %%
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %% [markdown]
# ## Scores

# %%
score = rmsle_cv(lasso)
print("\nLasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Lasso score: 0.0104 (0.0004)

# %%
score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# ElasticNet score: 0.0104 (0.0004)

# %%
score = rmsle_cv(KRR)
print("Kernel Ridge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Kernel Ridge score: 0.0104 (0.0006)

# %%
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Gradient Boosting score: 0.0103 (0.0005)

# %%
score = rmsle_cv(model_xgb)
print("\nXGBoost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# [16:03:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:03:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:04:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# XGBoost score: 0.0103 (0.0003)

# %%
score = rmsle_cv(model_lgb)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# LGBM score: 0.0103 (0.0004)

# %% [markdown]
# # Stacking models

# %%
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    # we define clones of the original models to fit the data in
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #Now we do the predictions for cloned models and average them
    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X) for model in self.models_
        ])
        return np.mean(predictions, axis=1)

# %%
averaged_models = AveragingModels(models = (ENet, GBoost, model_lgb, lasso, model_xgb))

score = rmsle_cv(averaged_models)
print(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [16:04:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [16:04:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [16:04:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [16:05:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [16:05:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#  Averaged base models score: 0.0099 (0.0004)

# %% [markdown]
# # Predicting House Prices

# %%
averaged_models = AveragingModels(models = (ENet, GBoost, model_lgb, lasso, model_xgb))
averaged_models.fit(x_train, y_train)
pred = np.expm1(averaged_models.predict(x_test))
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [16:30:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
submission = pd.DataFrame()
submission['Id'] = test_id
submission['SalePrice'] = pred
submission.to_csv('submission.csv', index=False)

# %%
submission
# Out:
#         Id      SalePrice
# 0     1461  110013.504991
# 1     1462  160692.757190
# 2     1463  178933.424879
# 3     1464  190065.925833
# 4     1465  194509.051358
# ...    ...            ...
# 1454  2915   84112.113297
# 1455  2916   88013.221829
# 1456  2917  151263.975183
# 1457  2918  116277.817549
# 1458  2919  235217.377041
#
# [1459 rows x 2 columns]
